# %%
import pandas as pd
import nltk
import re
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
# nltk.download('stopwords')
# nltk.download('punkt')
# nltk.download('wordnet')
wordnet_lemmatizer = WordNetLemmatizer()



df = pd.read_csv('comments.csv')

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\19785\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
cars = pd.read_csv('models.csv', names=['Brand', 'Model'])    
cars = cars.set_index('Brand')

brand_models = []
brands = []
models = []
no = ['car', 'seat', 'problem']
for brand in cars.index:
    if brand not in no:
        brand_models.append(brand)
        brands.append(brand)


for brand in cars['Model']:
    brand_models.append(brand)
    models.append(brand)

# %%
# def car_token(comments):
stop_words = set(stopwords.words('english'))

car_words = []
for words in df.comments:
    try:
        stuff = tokenizer.tokenize(words)
        car_words.append(stuff)
    except TypeError:
        pass

print(len(car_words))
count = 0 
for comments in car_words:
#     car_words[count] = [w for w in comments if w not in stop_words]
    car_words[count] = [w for w in comments if w in brand_models]
    count += 1
# Out:
# 4948

# %%
car_words = [x for x in car_words if x != []]
len(car_words)
# Out:
# 1671

# %%
words
# Out:
# 'I\'ll play, having recent time in a Sonata, Legacy, passat and Camry. Sat in the malibu and it seemed nice enough, but never drove one (just the previous generation thanks to Hertz).\n\nPassat: Had a 2012 base model rental recently and put on about 300 miles. 50K on it. overall, a nice enough drive. Huge car though (at least perception wise). Good seats. the 2.5L was kind of coarse, but that is not an issue. I have a lot of wheel time in a new Jetta with the 1.8T, and it is a nice powertrain, that gets good MPG. Downside, if you are in for a long term relationship, it is a VW. Overall, I think of this as a good highway car if you don\'t want overstuffed isolation.\n\nCamry: did a couple of test drives. I liked it more than expected. On local streets it seemed to handle fine, but I never tried hustling it. Seats did feel good, and as typical for a Camry, it was serene. I sat in a new style 2015 (no drive). interior seemed very similar. Reportedly the steering/handling dynamics have b
# ...

# %%
count = 0
for word in car_words:
    res = [i for n, i in enumerate(word) if i not in word[:n]]
    car_words[count] = sorted(res)
    count += 1

# %%
len(car_words)
# Out:
# 1671

# %%
words = []

count = 1
for w in df['comments']:
    try:
        already_used = []
        tokenizer = RegexpTokenizer(r'\w+')
        
        for word in tokenizer.tokenize(w):
            if word not in stop_words:
                if word not in already_used:
                    lem_word = wordnet_lemmatizer.lemmatize(word.lower())
                    words.append(lem_word)
    except TypeError:
        pass 

cars_brand_models = []
for word in words:
    if word in brand_models:
        cars_brand_models.append(word)

# %%
# cars[cars['Model'] == 'rlx'].index[0]

# bm = pd.Series(cars_brand_models) 

for place,model in enumerate(cars_brand_models):
    if model in models:
        replace = cars[cars['Model'] == str(model)].index[0]
        cars_brand_models[place] = replace

# %%
len(cars_brand_models)
# Out:
# 16748

# %%
from nltk import FreqDist
freq = FreqDist(cars_brand_models)
most_freq = freq.most_common(10)

# %%
most_freq
# Out:
# [('honda', 4573),
#  ('ford', 1855),
#  ('toyota', 1849),
#  ('hyundai', 1287),
#  ('nissan', 945),
#  ('mazda', 820),
#  ('volkswagen', 817),
#  ('subaru', 740),
#  ('chevrolet', 707),
#  ('sedan', 669)]

# %%
cw = car_words

for place,words in enumerate(cw):
    count = 0
    already_used = []
    for model in words:
        if model in models:
            if model not in already_used:
                replace = cars[cars['Model'] == str(model)].index[0]
                cw[place][count] = replace
                count += 1
            else:
                count += 1

# %%
len(cw)
# Out:
# 1671

# %%
count = 0
for word in cw:
    res = [i for n, i in enumerate(word) if i not in word[:n]]
    car_words[count] = sorted(res)
    count += 1
cw
# Out:
# [['kia'],
#  ['car'],
#  ['car'],
#  ['car', 'seat'],
#  ['hyundai', 'kia', 'sonatas'],
#  ['car', 'seat'],
#  ['car'],
#  ['car'],
#  ['car'],
#  ['sedan'],
#  ['sedan'],
#  ['hyundai', 'kia', 'sonatas'],
#  ['sedan'],
#  ['car'],
#  ['car', 'sedan', 'sedans'],
#  ['sedan'],
#  ['sedan'],
#  ['sedan'],
#  ['sedan'],
#  ['car'],
#  ['seat'],
#  ['car'],
#  ['car', 'chevrolet', 'ford', 'fusion', 'malibu'],
#  ['acura', 'car'],
#  ['sedan'],
#  ['sedan'],
#  ['car', 'sedan'],
#  ['car'],
#  ['honda'],
#  ['honda'],
#  ['sedan'],
#  ['chrysler', 'seat'],
#  ['sedan'],
#  ['sedan'],
#  ['car'],
#  ['car', 'sedan'],
#  ['sedan'],
#  ['sedan'],
#  ['seat'],
#  ['sedan', 'toyota'],
#  ['sedan', 'toyota'],
#  ['honda'],
#  ['honda', 'toyota'],
#  ['seat'],
#  ['car'],
#  ['seat'],
#  ['car', 'sedan', 'volkswagen'],
#  ['problem', 'toyota', 'volkswagen'],
#  ['problem', 'toyota', 'volkswagen'],
#  ['problem'],
#  ['chevrolet', 'malibu'],
#  ['sedan'],
#  ['chevrolet', 'malibu'],
# ...

# %%
flat_list = []
for sublist in cw:
    flat_list.append(' '.join(sublist))

# %%
def wm2df(wm, feat_names):
    
    # create an index for each row
    doc_names = ['Doc{:d}'.format(idx) for idx, _ in enumerate(wm)]
    df = pd.DataFrame(data=wm.toarray(), index=doc_names,
                      columns=feat_names)
    return(df)
  
# set of documents
corpora = flat_list

# instantiate the vectorizer object
cvec = CountVectorizer(lowercase=False)

# convert the documents into a document-term matrix
wm = cvec.fit_transform(corpora)

# retrieve the terms found in the corpora
tokens = cvec.get_feature_names()

# create a dataframe from the matrix
df = wm2df(wm, tokens)

# %%
# mask = [df['acura'] == 0]
df[df['ford'] != 0]
# Out:
#          acura  audi  bmw  buick  camry  car  cars  chevrolet  chrysler  \
# Doc22        0     0    0      0      0    1     0          1         0
# Doc57        0     0    0      0      0    1     0          0         0
# Doc86        0     0    0      0      0    0     0          0         0
# Doc87        0     0    0      0      0    1     0          0         0
# Doc88        0     0    0      0      0    1     0          0         0
# Doc91        0     0    0      0      0    0     0          0         0
# Doc92        0     0    0      0      0    0     0          0         0
# Doc178       0     0    0      0      0    0     0          0         0
# Doc181       0     0    0      0      0    0     0          0         0
# Doc185       0     0    0      0      0    0     0          0         0
# Doc197       0     0    0      0      0    0     0          0         0
# Doc198       0     0    0      0      0    0     0          0         0
# ...

# %%
most_freq
# Out:
# [('honda', 4573),
#  ('ford', 1855),
#  ('toyota', 1849),
#  ('hyundai', 1287),
#  ('nissan', 945),
#  ('mazda', 820),
#  ('volkswagen', 817),
#  ('subaru', 740),
#  ('chevrolet', 707),
#  ('sedan', 669)]

# %%
honda = [df['honda'] != 0]
ford1 = df[df['ford'] != 0]

hf = df[(df['ford']!=0) & (df['honda']!=0)]

(len(df)*len(hf))/(len(honda)*len(ford1))
# Out:
# 143.74193548387098

# %%
len(hf)
# Out:
# 8
